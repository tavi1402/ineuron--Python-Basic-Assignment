# %% [markdown]
# ### 1.To what does a relative path refer ?
#
# Ans: A relative path refers to a location that is relative to a current directory.
# - There are no of ways to get the relative path, Few are:
# - example:
#
#     1 import os
#     os. getcwd()
#
#
#     2 pwd

# %%
pwd # Prints the current Working Directory
# Out:
# '/Users/sannaved/Desktop'

# %%
import os
os. getcwd() # Prints the current Working Directory
# Out:
# '/Users/sannaved/Desktop'

# %% [markdown]
# ### 2.Where does an absolute path start with your Operating System ?
#
# Ans:
# - An absolute path is a path that contains the entire path to the file or directory that you need to access.
# - This path will begin at the home directory of your computer and will end with the file or directory that you wish to access .
# - Absolute paths are used in websites and operating systems for locating files and folders. An absolute path is also known as an absolute pathname or full path.
# ```
#     - In Linux based systems the absolute path starts with /.
#     - Where as in Windows based systems absolute path starts with C:,
#     - in macos based systems the absolute path starts with /. ('/Users/sannaved')

# %% [markdown]
# ### 3.What does the functions os.getcwd() and os.chdir() do ?
#
# Ans:
#
# - getcwd() : CWD stands for Current Working Directory. This function allows you to see what your current working directory is.
# - chdir("path-to-dir") : Short for CHange DIRectory, this method in Python used to change the current working directory to specified path or this function allows you to set the current working directory to a path of your choice
# - These functions are similar to linux commands pwd and cd

# %%
import os
print(os.getcwd())
# Out:
# /Users/sannaved/Desktop

# %%
path = '/Users/sannaved/Desktop'
os.chdir(path)
print(os.getcwd())
# Out:
# /Users/sannaved/Desktop

# %% [markdown]
# ### 4.What are . and .. folders ?
#
# Ans:
# - . Represents the Current Directory Whereas
# - .. Represents the Parent Directory of the Current Directory

# %% [markdown]
# ### 5.In C:\bacon\eggs\spam.txt which part is the dir name and which part is the base name ?
#
# Ans:
# ```
# For C:\bacon\eggs\spam.txt
#     The dir name is C:\bacon\eggs
#     The Base name is spam.txt

# %%
import os
path = r'C:\bacon\eggs\spam.txt'
# print(os.path.dirname(path))
print(os.path.basename(path))
# Out:
# C:\bacon\eggs\spam.txt

# %% [markdown]
# ### 6.What are the three mode arguments that can be passed to the open() function ?
#
# Ans:
# - The open() function opens a file, and returns it as a file object.
# - A file can be Accessed in python using open() function. open function takes two arguments filename and mode of operation (optional).
# - If mode is not provided the default mode of opening is read mode
# - open(filename, mode)- Syntax
#
#
# ```
# "r" - Read Mode - Default value. Opens a file for reading, error if the file does not exist
# "w" - Write Mode - Opens a file for writing, creates the file if it does not exist
# "a" - Append Mode - Opens a file for appending, creates the file if it does not exist or With this mode the     user can append the data without overwriting any already existing data in the file.
# "x" – Exclusive Creating Mode: This mode is for the sole purpose of creating new files. Use this mode if you   know the file to be written doesn’t exist beforehand.
# "r+" – Read/Write Mode: Use this mode if you need to simultaneously read and write to a file.
# "a+" – Append and Read Mode: In this mode you can read and append the data without overwriting the original     file.
# ```
#
# - In addition you can specify if the file should be handled as binary or text mode
#
# ```
# "t" - Text - Default value. Text mode
# "b" - Binary - Binary mode (e.g. images)
# ```

# %% [markdown]
# ### 7.What happens if an existing file is opened in write mode ?
#
# Ans:
# - This will overwrite any existing file with the same name.
# - If the given file does not exist, a new one will be created.

# %% [markdown]
# ### 8.How do you tell the difference between read() and readlines() ?
#
# Ans:
# - read() - will read the whole file at once.The read() would treat each character in the file separately, meaning that the iteration would happen for every character.
#
# - readline() - only reads a single line of the file. This means that if the first line of the file were three lines long, the readline() function would only parse (or iterate/operate) on the first line of the file.
#
#
# ![read_file.png](attachment:read_file.png)

# %%
with open("tavi.txt", 'w') as f:
    f.write('''It is not simple to extract content from websites
In fact, web scraping is becoming widely popular due to the easy accessibility of data. 
Moreover, web scraping has gained momentum due to efficient ways of copying large chunks of information online . 
Most businesses use web scraping techniques to quickly examine competitors and their business portfolios.''')

# %%
with open("tavi.txt", "r") as f:
    data = f.read()
    print(data)
# Out:
# It is not simple to extract content from websites
# In fact, web scraping is becoming widely popular due to the easy accessibility of data.
# Moreover, web scraping has gained momentum due to efficient ways of copying large chunks of information online .
# Most businesses use web scraping techniques to quickly examine competitors and their business portfolios.

# %%
with open("tavi.txt", "r") as f:
    data = f.readline()
    print(data)
# Out:
# It is not simple to extract content from websites

# %% [markdown]
# ### 9.What data structure does a shelf value resemble ?
#
# Ans: A shelf value resembles a dictionary value; it has keys and values, along with keys() and values() methods that work similarly to the dictionary methods of the same names.
