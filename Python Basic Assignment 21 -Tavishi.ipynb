# %%
1. Add the current date to the text file today.txt as a string.
2. Read the text file today.txt into the string today_string
3. Parse the date from today_string.
4. List the files in your current directory
5. Create a list of all of the files in your parent directory (minimum five files should be available).
6. Use multiprocessing to create three separate processes. Make each one wait a random number of
seconds between one and five, print the current time, and then exit.
7. Create a date object of your day of birth.
8. What day of the week was your day of birth?
9. When will you be (or when were you) 10,000 days old?

# %% [markdown]
# ## 1. Add the current date to the text file today.txt as a string.

# %%
from datetime import date
now = date.today()
now_str = now.isoformat()
with open('today.txt', 'wt') as output:
    print(now_str, file=output)

# %% [markdown]
# ## 2. Read the text file today.txt into the string today_string

# %%
with open('today.txt', 'rt') as input:
    today_string = input.read()
    
today_string
# Out:
# '2022-08-12\n'

# %% [markdown]
# ## 3. Parse the date from today_string.

# %%
from datetime import datetime
fmt = '%Y-%m-%d\n'
datetime.strptime(today_string, fmt)
# Out:
# datetime.datetime(2022, 8, 12, 0, 0)

# %% [markdown]
# ## 4. List the files in your current directory

# %%
import os
for folders, subfolders, files in os.walk(os.getcwd()):
    for file in files:
        print(file)
# Out:
# Assignment_23_Soln.ipynb
# logistic regression .ipynb
# .condarc
# Python Basic Assignment 20 -Tavishi.ipynb
# mylocation2.html
# Untitled1.ipynb
# .DS_Store
# .CFUserTextEncoding
# .xonshrc
# Untitled3.ipynb
# Untitled.ipynb
# Assignment_21_Soln.ipynb
# .zshrc
# today.txt
# Untitled4.ipynb
# Untitled6.ipynb
# Untitled2.ipynb
# Assignment_24_Soln.ipynb
# Python advance programming assignment_1 tavishi.ipynb
# Python Basic Assignment 11 -Tavishi.ipynb
# abc.zip
# mylocation.html
# .tcshrc
# ML- linear , Ridge, Lasso regression.ipynb
# Assignment_22_Soln.ipynb
# xyz.zip
# EDA - India's Weather And Its Impact On Renewable Energy.ipynb
# Python advance programming assignment_2 tavishi.ipynb
# Python Basic Assignment 10 -Tavishi.ipynb
# test.txt
# live location .ipynb
# Decision Tree .ipynb
# Assignment_25_Soln.ipynb
# .bash_profile
# eda-7-million-company-dataset- tavishi .ipynb
# config.fish
# .localized
# .Media Preferences.plist
# id.strings
# es.strings
# no.strings
# zh_TW.strings
# fi.strings
# ru.strings
# en.strings
# es_419.strings
# he.strings
# uk.strings
# fr_CA.strings
# nl.strings
# de.strings
# ja.strings
# sk.strings
# hr.strings
# el.strings
# th.strings
# zh_CN.strings
# cs.strings
# sv.strings
# pl.strings
# zh_HK.strings
# en_GB.strings
# en_AU.strings
# da.strings
# fr.strings
# ro.strings
# pt.strings
# pt_PT.strings
# ms.strings
# ko.strings
# hu.strings
# hi.strings
# tr.strings
# vi.strings
# ca.strings
# ar.strings
# it.strings
# Library.musicdb
# Library Preferences.musicdb
# .localized
# history.sqlite
# README
# .DS_Store
# .localized
# uTorrentWeb.dmg
# Python Basic Assignment 19 -Tavishi.ipynb
# Python Basic Assignment 16 -Tavishi.ipynb
# Python Basic Assignment 17 -Tavishi.ipynb
# Python Basic Assignment 18 -Tavishi.ipynb
# Python Basic Assignment 15 -Tavishi.ipynb
# Python Basic Assignment 14 -Tavishi.ipynb
# Unknown.jpeg
# Python Basic Assignment 13 -Tavishi.ipynb
# Screenshot 2022-08-11 at 2.48.32 PM.png
# Screenshot 2022-08-11 at 2.48.39 PM.png
# .DS_Store
# 2.1 Kaggle Bluebook for Bulldozers Competition.html
# 12. Fitting A Machine Learning Model.srt
# 14. Challenge What's wrong with splitting data after filling it.html
# 17. RandomizedSearchCV.srt
# 4. Step 1~4 Framework Setup.srt
# 1. Section Overview.mp4
# 3. Project Environment Setup.mp4
# 2. Project Overview.mp4
# 21. Feature Importance.srt
# 8. Feature Engineering.srt
# 20. Making Predictions.srt
# 19. Preproccessing Our Data.mp4
# 10. Filling Missing Numerical Values.srt
# 15. Custom Evaluation Function.srt
# 21.2 End-to-end Bluebook Bulldozer Regression Notebook (same as in videos).html
# 6. Exploring Our Data.srt
# 11. Filling Missing Categorical Values.mp4
# 13. Splitting Data.mp4
# 7. Exploring Our Data 2.srt
# 9. Turning Data Into Numbers.srt
# 18. Improving Hyperparameters.srt
# 16. Reducing Data.mp4
# 15. Custom Evaluation Function.mp4
# 2.3 End-to-end Bluebook Bulldozer Regression Notebook (same as in videos).html
# 10.1 Pandas Categorical Datatype Documentation.html
# 6. Exploring Our Data.mp4
# 11. Filling Missing Categorical Values.srt
# 13. Splitting Data.srt
# 9. Turning Data Into Numbers.mp4
# 21.1 End-to-end Bluebook Bulldozer Regression Notebook (with annotations).html
# 7. Exploring Our Data 2.mp4
# 16. Reducing Data.srt
# 18. Improving Hyperparameters.mp4
# 12. Fitting A Machine Learning Model.mp4
# 1. Section Overview.srt
# 17. RandomizedSearchCV.mp4
# 4. Step 1~4 Framework Setup.mp4
# 5. Downloading the data for the next two projects.html
# 2. Project Overview.srt
# 2.2 End-to-end Bluebook Bulldozer Regression Notebook (with annotations).html
# 3. Project Environment Setup.srt
# 21. Feature Importance.mp4
# 19. Preproccessing Our Data.srt
# 10. Filling Missing Numerical Values.mp4
# 20. Making Predictions.mp4
# 8. Feature Engineering.mp4
# 2.4 Structured Data Projects on GitHub.html
# 4. Your First Day.srt
# 3. Exercise Meet The Community.html
# 2. Join Our Online Classroom!.html
# 1. Course Outline.srt
# 1. Course Outline.mp4
# 4. Your First Day.mp4
# 11. Jupyter Notebook Walkthrough.mp4
# 1. Section Overview.mp4
# 10.1 Conda documentation on sharing an environment.html
# 4. Conda Environments.mp4
# 8. Windows Environment Setup 2.srt
# 3.4 Getting your computer ready for machine learning How, what and why you should use Anaconda, Miniconda and Conda (blog post).html
# 4. Conda Environments.srt
# 8. Windows Environment Setup 2.mp4
# 13. Jupyter Notebook Walkthrough 3.mp4
# 5. Mac Environment Setup.mp4
# 9. Linux Environment Setup.html
# 1. Section Overview.srt
# 10. Sharing your Conda Environment.html
# 17. Variables.mp4
# 16. Optional bin() and complex.srt
# 11. Numbers.srt
# 17.1 Python Keywords.html
# 10. How To Succeed.html
# 19. Augmented Assignment Operator.srt
# 20. Strings.mp4
# 22. Type Conversion.mp4
# 14.1 Exercise Repl.html
# 12. Math Functions.mp4
# 13. DEVELOPER FUNDAMENTALS I.mp4
# 25. String Indexes.mp4
# 21. String Concatenation.mp4
# 24. Formatted Strings.mp4
# 2. Python Interpreter.srt
# 15. Exercise Operator Precedence.html
# 23. Escape Sequences.srt
# 18. Expressions vs Statements.srt
# 2.1 python.org.html
# 15.1 Exercise Repl.html
# 1. What Is A Programming Language.mp4
# 14. Operator Precedence.mp4
# 19.1 Exercise Repl.html
# 2. Python Interpreter.mp4
# 24.1 Exercise Repl.html
# 18. Expressions vs Statements.mp4
# 23. Escape Sequences.mp4
# 14. Operator Precedence.srt
# 1. What Is A Programming Language.srt
# 35. List Methods.mp4
# 17. Variables.srt
# 11. Numbers.mp4
# 16. Optional bin() and complex.mp4
# 38. Common List Patterns.mp4
# 41. Dictionaries.mp4
# 19. Augmented Assignment Operator.mp4
# 22. Type Conversion.srt
# 20. Strings.srt
# 11.1 Floating point numbers.html
# 13. DEVELOPER FUNDAMENTALS I.srt
# 12. Math Functions.srt
# 16.1 Base Numbers.html
# 21. String Concatenation.srt
# 24. Formatted Strings.srt
# 1. Section Overview.mp4
# 8. Quick Note Upcoming Video.html
# 4. What Is A Data Engineer 2.mp4
# 9. Optional OLTP Databases.mp4
# 10. Optional Learn SQL.html
# 12. Apache Spark and Apache Flink.srt
# 3. What Is A Data Engineer.srt
# 13. Kafka and Stream Processing.srt
# 5. What Is A Data Engineer 3.mp4
# 7. Types Of Databases.srt
# 2. What Is Data.mp4
# 11. Hadoop, HDFS and MapReduce.srt
# 1. Data Engineering Introduction.mp4
# 6. What Is A Data Engineer 4.srt
# 5. What Is A Data Engineer 3.srt
# 2. What Is Data.srt
# 7.1 OLTP vs OLAP.html
# 7. Types Of Databases.mp4
# 11. Hadoop, HDFS and MapReduce.mp4
# 1. Data Engineering Introduction.srt
# 7.2 A Primer on ACID Transactions.html
# 6. What Is A Data Engineer 4.mp4
# 4. What Is A Data Engineer 2.srt
# 9. Optional OLTP Databases.srt
# 12. Apache Spark and Apache Flink.mp4
# 3. What Is A Data Engineer.mp4
# 2.1 Kaggle.html
# 13. Kafka and Stream Processing.mp4
# 15. Tuning Hyperparameters.mp4
# 14. TuningImproving Our Model.srt
# 22. Finding The Most Important Features.mp4
# 10. Finding Patterns 3.srt
# 19. Evaluating Our Model.srt
# 1. Section Overview.mp4
# 23. Reviewing The Project.mp4
# 3. Project Environment Setup.mp4
# 2. Project Overview.mp4
# 4. Optional Windows Project Environment Setup.srt
# 17. Tuning Hyperparameters 3.mp4
# 7. Exploring Our Data.mp4
# 20. Evaluating Our Model 2.mp4
# 23.2 End-to-end Heart Disease Classification Notebook (with annotations).html
# GetFreeCourses.Co.url
# 2.1 End-to-end Heart Disease Classification Notebook (with annotations).html
# 8. Finding Patterns.mp4
# 5. Step 1~4 Framework Setup.srt
# 11. Preparing Our Data For Machine Learning.srt
# 7.1 heart-disease.csv
# 12. Choosing The Right Models.mp4
# 13. Experimenting With Machine Learning Models.srt
# 21. Evaluating Our Model 3.mp4
# 9. Finding Patterns 2.srt
# 16. Tuning Hyperparameters 2.mp4
# 6. Getting Our Tools Ready.mp4
# 8. Finding Patterns.srt
# 5. Step 1~4 Framework Setup.mp4
# 11. Preparing Our Data For Machine Learning.mp4
# 23.1 End-to-end Heart Disease Classification Notebook (same as in videos).html
# 12. Choosing The Right Models.srt
# 13. Experimenting With Machine Learning Models.mp4
# 16. Tuning Hyperparameters 2.srt
# 21. Evaluating Our Model 3.srt
# 9. Finding Patterns 2.mp4
# 2.2 Structured Data Projects on GitHub.html
# 6. Getting Our Tools Ready.srt
# 22. Finding The Most Important Features.srt
# 14. TuningImproving Our Model.mp4
# 15. Tuning Hyperparameters.srt
# 10. Finding Patterns 3.mp4
# 1. Section Overview.srt
# 23. Reviewing The Project.srt
# 19. Evaluating Our Model.mp4
# 2.3 End-to-end Heart Disease Classification Notebook (same as in videos).html
# 2. Project Overview.srt
# 18. Quick Note Confusion Matrix Labels.html
# 3. Project Environment Setup.srt
# 17. Tuning Hyperparameters 3.srt
# 4. Optional Windows Project Environment Setup.mp4
# 7. Exploring Our Data.srt
# 20. Evaluating Our Model 2.srt
# 2.1 How to Think About Communicating and Sharing Your Work (blog post).html
# 1. Section Overview.mp4
# 6.2 fast_template by fast.ai (a template you can use for your blog on GitHub Pages).html
# 8. Communicating and sharing your work Further reading.html
# 7. Storytelling.srt
# 4. Communicating With Co-Workers.mp4
# 6. Communicating With Outside World.mp4
# 6.1 Devblog by Hashnode (an easy and free way to create a blog you own).html
# 2. Communicating Your Work.mp4
# 3. Communicating With Managers.srt
# 5. Weekend Project Principle.srt
# 2. Communicating Your Work.srt
# 5. Weekend Project Principle.mp4
# 3. Communicating With Managers.mp4
# 1. Section Overview.srt
# 7. Storytelling.mp4
# 4. Communicating With Co-Workers.srt
# 6. Communicating With Outside World.srt
# 16. Choosing The Right Model For Your Data.mp4
# 15. Getting Your Data Ready Handling Missing Values With Scikit-learn.mp4
# 5. Quick Note Upcoming Videos.html
# 38. Evaluating A Model With Cross Validation and Scoring Parameter.mp4
# 6. Scikit-learn Cheatsheet.mp4
# 31. Evaluating A Classification Model 4 (Confusion Matrix).srt
# 8. Optional Debugging Warnings In Jupyter.srt
# 4. Refresher What Is Machine Learning.mp4
# 35. Evaluating A Regression Model 2 (MAE).mp4
# 40. Improving A Machine Learning Model.mp4
# 49. Putting It All Together 2.mp4
# 26. Evaluating A Machine Learning Model 2 (Cross Validation).mp4
# 20. Choosing The Right Model For Your Data 3 (Classification).mp4
# 36. Evaluating A Regression Model 3 (MSE).mp4
# 31.1 Notebook from video with updated confusion matrix labels.html
# 49.1 Introduction to Scikit-Learn Jupyter Notebook (from the videos).html
# 49. Putting It All Together 2.srt
# 9. Getting Your Data Ready Splitting Your Data.mp4
# 39. Evaluating A Model With Scikit-learn Functions.mp4
# 32. Evaluating A Classification Model 5 (Confusion Matrix).mp4
# 38. Evaluating A Model With Cross Validation and Scoring Parameter.srt
# 50. Scikit-Learn Practice.html
# 31. Evaluating A Classification Model 4 (Confusion Matrix).mp4
# 49.2 Introduction to Scikit-Learn Jupyter Notebook (with annotations).html
# 35. Evaluating A Regression Model 2 (MAE).srt
# 4. Refresher What Is Machine Learning.srt
# 8. Optional Debugging Warnings In Jupyter.mp4
# 1. Milestone Projects!.html
# 9. Plotting From Pandas DataFrames.mp4
# 6. Histograms And Subplots.srt
# 8. Quick Tip Data Visualizations.srt
# 7. Subplots Option 2.mp4
# 12. Plotting from Pandas DataFrames 3.mp4
# 6. Histograms And Subplots.mp4
# 8. Quick Tip Data Visualizations.mp4
# 1. Statistics and Mathematics.html
# 1. Section Overview.mp4
# 10. Standard Deviation and Variance.mp4
# 8. Manipulating Arrays.mp4
# 12. Dot Product vs Element Wise.mp4
# 4. NumPy DataTypes and Attributes.mp4
# 16. Turn Images Into NumPy Arrays.mp4
# 1. Section Overview.srt
# 6. NumPy Random Seed.mp4
# 34. nonlocal Keyword.mp4
# 9. is vs ==.mp4
# 26. Methods vs Functions.mp4
# 27. Docstrings.mp4
# 3. Indentation In Python.mp4
# 29. args and kwargs.srt
# 10. For Loops.mp4
# 1. Breaking The Flow.srt
# 7. Logical Operators.mp4
# 45. Modules in Python.mp4
# 28. Clean Code.mp4
# 40. reduce().mp4
# 46. Quick Note Upcoming Videos.html
# 1. Breaking The Flow.mp4
# 7. Logical Operators.srt
# 8. Exercise Logical Operators.mp4
# 45. Modules in Python.srt
# 47. Optional PyCharm.mp4
# 9. is vs ==.srt
# 26. Methods vs Functions.srt
# 48. Packages in Python.mp4
# 27. Docstrings.srt
# 29. args and kwargs.mp4
# 1. What Is Machine Learning.mp4
# 6. Types of Machine Learning.mp4
# 9. CWD Git + Github.srt
# 5. Quick Note Upcoming Videos.html
# 1. Endorsements On LinkedIn.html
# 13. Coding Challenges.html
# 12. Contributing To Open Source 2.srt
# 14. Exercise Contribute To Open Source.html
# 3. What If I Don't Have Enough Experience.srt
# 6. JTS Learn to Learn.mp4
# 4. Learning Guideline.html
# 11. Contributing To Open Source.srt
# 7. JTS Start With Why.mp4
# 10. CWD Git + Github 2.mp4
# 8. Quick Note Upcoming Videos.html
# 12. Contributing To Open Source 2.mp4
# 2. Quick Note Upcoming Video.html
# 3. What If I Don't Have Enough Experience.mp4
# 6. JTS Learn to Learn.srt
# 11. Contributing To Open Source.mp4
# 7. JTS Start With Why.srt
# 10. CWD Git + Github 2.srt
# 9. CWD Git + Github.mp4
# 13. Optional Reloading Colab Notebook.mp4
# 7. Setting Up Our Data.mp4
# 4.5 Introduction to Google Colab example notebook.html
# 40. Training Model On Full Dataset.mp4
# 25.3 MobileNetV2 (the model we're using) on TensorFlow Hub.html
# 3. Setting Up With Google.html
# 17. Creating Our Own Validation Set.srt
# 1. Section Overview.mp4
# 41. Making Predictions On Test Images.mp4
# 5. Google Colab Workspace.srt
# 28. Building A Deep Learning Model 4.mp4
# 36. Visualizing Model Predictions.srt
# 12.2 Google Colab Example of GPU speed up versus CPU.html
# 22. Visualizing Our Data.srt
# 23. Preparing Our Inputs and Outputs.srt
# 21. Turning Data Into Batches 2.mp4
# 8. Setting Up Our Data 2.mp4
# 38. Visualizing And Evaluate  Model Predictions 3.mp4
# 30. Evaluating Our Model.srt
# 16. Turning Data Labels Into Numbers.mp4
# 31.1 Early Stopping Callback (a way to stop your model from training when it stops improving) Documentation.html
# 25.2 Andrei Karpathy's talk on AI at Tesla.html
# 10. Optional TensorFlow 2.0 Default Issue.srt
# 19. Preprocess Images 2.mp4
# 37. Visualizing And Evaluate Model Predictions 2.srt
# 35.1 TensorFlow documentation for the unbatch() function.html
# 17.1 Blog post by Rachel Thomas (of fast.ai) on how and why you should create a validation set.html
# 11. Using A GPU.srt
# 11.1 Google Colab example GPU usage.html
# 23.1 TensorFlow Hub (resource for pre-trained deep learning models and more).html
# 14. Loading Our Data Labels.mp4
# 25. Building A Deep Learning Model.mp4
# 4.4 Google Colab (our workspace for the upcoming project).html
# 42. Submitting Model to Kaggle.srt
# 43.1 End-to-end Dog Vision Notebook (from the videos).html
# 9. Importing TensorFlow 2.srt
# 31. Preventing Overfitting.srt
# 18. Preprocess Images.mp4
# 18.2 Documentation for loading images in TensorFlow.html
# 39. Saving And Loading A Trained Model.mp4
# 6. Uploading Project Data.mp4
# 29. Summarizing Our Model.srt
# 6.1 Google Colab IO example (how to get data in and out of your Colab notebook).html
# 20. Turning Data Into Batches.mp4
# 10.1 Loading TensorFlow 2.0 into a Colab Notebook (if it isn't the default).html
# 35. Transform Predictions To Text.srt
# 4.3 End-to-end Dog Vision Notebook (the project we'll be working through).html
# 12. Optional GPU and Google Colab.mp4
# 32. Training Your Deep Neural Network.srt
# 43. Making Predictions On Our Images.mp4
# 2. Deep Learning and Unstructured Data.srt
# 27. Building A Deep Learning Model 3.srt
# 4. Setting Up Google Colab.srt
# 33. Evaluating Performance With TensorBoard.srt
# 25.1 PyTorch Hub (PyTorch version of TensorFlow Hub).html
# 34. Make And Transform Predictions.srt
# 15. Preparing The Images.srt
# 26. Building A Deep Learning Model 2.srt
# 14.1 Documentation on how many images Google recommends for image problems.html
# 14. Loading Our Data Labels.srt
# 27.3 The Softmax Function (activation function we use in our model).html
# 42. Submitting Model to Kaggle.mp4
# 24. Optional How machines learn and what's going on behind the scenes.html
# 25. Building A Deep Learning Model.srt
# 18. Preprocess Images.srt
# 9. Importing TensorFlow 2.mp4
# 31. Preventing Overfitting.mp4
# 26.1 Keras in TensorFlow Overview Documentation.html
# 44. Finishing Dog Vision Where to next.html
# 39. Saving And Loading A Trained Model.srt
# 6. Uploading Project Data.srt
# 4.2 Google Colab IO example (how to get data in and out of your Colab notebook).html
# 20. Turning Data Into Batches.srt
# 41.1 Dog Vision Prediction Probabilities Array.html
# 35. Transform Predictions To Text.mp4
# 29. Summarizing Our Model.mp4
# 25.4 TensorFlow Hub (resource for pre-trained deep learning models and more).html
# 6.2 Kaggle Dog Breed Identification Competition Data.html
# 28.1 [Article] How to choose loss & activation functions when building a deep learning model.html
# 12. Optional GPU and Google Colab.srt
# 32. Training Your Deep Neural Network.mp4
# 43. Making Predictions On Our Images.srt
# 42.1 Dog Vision Predictions with MobileNetV2 Ready for Kaggle Submission.html
# 27. Building A Deep Learning Model 3.mp4
# 2. Deep Learning and Unstructured Data.mp4
# 4.1 Kaggle Dog Breed Identification Competition (the basis of our upcoming project).html
# 15. Preparing The Images.mp4
# 26. Building A Deep Learning Model 2.mp4
# 33. Evaluating Performance With TensorBoard.mp4
# 4. Setting Up Google Colab.mp4
# 34. Make And Transform Predictions.mp4
# 21.1 Yann LeCun's (OG of deep learning) Tweet on Batch Sizes.html
# 7. Setting Up Our Data.srt
# 13. Optional Reloading Colab Notebook.srt
# 27.1 Step by step breakdown of a convolutional neural network (what MobileNetV2 is made of).html
# 18.1 TensorFlow guidelines for loading all kinds of data (turning your data into Tensors).html
# 40. Training Model On Full Dataset.srt
# 43.2 End-to-end Dog Vision Notebook (with annotations).html
# 1. Section Overview.srt
# 5.1 Google Colab FAQ (things you should know about Google Colab).html
# 41. Making Predictions On Test Images.srt
# 17. Creating Our Own Validation Set.mp4
# 36. Visualizing Model Predictions.mp4
# 12.1 Introduction to Google Colab example notebook.html
# 30.1 TensorBoard Callback Documentation.html
# 22. Visualizing Our Data.mp4
# 23. Preparing Our Inputs and Outputs.mp4
# 28. Building A Deep Learning Model 4.srt
# 5. Google Colab Workspace.mp4
# 21. Turning Data Into Batches 2.srt
# 8. Setting Up Our Data 2.srt
# 16. Turning Data Labels Into Numbers.srt
# 5.2 Google Colab (our workspace for the upcoming project).html
# 30. Evaluating Our Model.mp4
# 25.5 Papers with Code (a great resource for some of the best machine learning papers with code examples).html
# 38. Visualizing And Evaluate  Model Predictions 3.srt
# 10. Optional TensorFlow 2.0 Default Issue.mp4
# 19. Preprocess Images 2.srt
# 37. Visualizing And Evaluate Model Predictions 2.mp4
# 27.2 MobileNetV2 (the model we're using) architecture explanation by Sik-Ho Tsang.html
# 11. Using A GPU.mp4
# 1. Section Overview.mp4
# 5. Types of Data.mp4
# 10. Modelling - Tuning.mp4
# 6. Types of Evaluation.mp4
# 1. Section Overview.srt
# 5. Types of Data.srt
# Info.plist
# PkgInfo
# CodeResources
# ogr2ogr
# mysql
# MySQLWorkbench
# ogrinfo
# mysqldump
# wbcopytables
# db.mysql.parser.grt.dylib
# db.mysql.grt.dylib
# db.mysql.query.grt.dylib
# db.mysql.diff.reporting.wbp.dylib
# wb.model.grt.dylib
# db.mysql.wbp.dylib
# db.search.wbp.dylib
# db.mysql.sqlparser.grt.dylib
# wb.model.snippets.wbp.dylib
# utilities.grt.dylib
# Info.plist
# CodeResources
# wb.printing
# wb.printing.wbp.dylib
# Info.plist
# CodeResources
# db.mysql.editors
# RoleEditor.nib
# MySQLRelationshipEditor.nib
# PrivilegesTab.nib
# MySQLTableEditor.nib
# UserEditor.nib
# MySQLRoutineEditor.nib
# MySQLRoutineGroupEditor.nib
# MySQLSchemaEditor.nib
# MySQLViewEditor.nib
# db.mysql.editors.wbp.dylib
# Info.plist
# CodeResources
# wb.model.editors
# WbModelStoredNoteEditor.nib
# WbPhysicalLayerEditor.nib
# WbModelImageEditor.nib
# WbModelNoteEditor.nib
# wb.model.editors.wbp.dylib
# snippet_py.png
# collapsing_panel_grid_large_icons.png
# snippet_htm.png
# ac_table.png
# tiny_align_v_bottom.png
# ps_switcher_text_dark.png
# GrtObject.add.48x48.png
# wb_layer.png
# db.Column.nn.16x16.png
# audit_log@2x.png
# dashboard_header_network_light@2x.png
# qe_sql-editor-tb-icon_explain@2x.png
# ac_view.png
# home_screen_close_light.png
# switcher_bottom_off.png
# db.Role.16x16.png
# record_fetch_next@2x.png
# qe_main-tb-icon_add-sql-editor_mac@2x.png
# workbench.physical.Layer.16x16.png
# mysql-status-separator.png
# switcher_left_off@2x.png
# Close_18x18.png
# db.Column.pk.11x11.png
# ps_easysetup_logo.png
# page_restore.png
# switcher_bottom_on@2x.png
# output_type-formeditor.png
# message_wb_lock.png
# check.png
# title_table_inspector@2x.png
# home_screen_close_dark.png
# object_inspector_mac.png
# record_sort_asc.png
# GrtObject.add.24x24.png
# admin_meb_backup.png
# section_unexpandable.png
# db.Column.fknn.16x16.png
# wb_db_routinegroup.png
# db.Role.add.16x16.png
# db.Schema.selected.32x32.png
# dashboard_header_mysql_dark.png
# qe_main-tb-icon_open-sql-file_mac.png
# qe_sql-editor-tb-icon_zoom-in@2x.png
# wb_rel_1n.png
# tab.overview.physical.16x16.png
# wb_tile_number_dark.png
# db.Schema.side.16x16.png
# ps_switcher_disabled_off@2x.png
# tiny_more_space.png
# record_edit@2x.png
# sqlide_power_export_wizard.py
# rubber.png
# statusbar_shell.png
# mysql-logo-58.png
# switcher_right_on@2x.png
# tab_icon_plugin@2x.png
# switcher_right_off@2x.png
# DotGrey.png
# qe_sql-editor-explain-tb-overview.png
# db.Table.add.48x48.png
# wb_rel_1n_pick_dark.png
# migration_icon_32x32.png
# dashboard_header_network_dark.png
# db.Column.pk.side.16x16@2x.png
# JS_Datatype_Number.png
# dashboard_header_innodb_light.png
# wb_hand.png
# record_refresh@2x.png
# os_utils.py
# qe_sql-editor-tb-icon_stop.png
# db.mgmt.Connection.add.16x16.png
# ps_switcher_default_off.png
# background_top_shadow.png
# Refresh_16x16.png
# mysql-logo-55@2x.png
# title_connections@2x.png
# db.Index.many.side.16x16@2x.png
# MacWizardBackground.png
# wb_tab_close_light@2x.png
# mysql-logo-00@2x.png
# JS_Datatype_Bin@2x.png
# qe_sql-editor-tb-icon_stop-on-error-on.png
# wb_item_overlay_inspector.png
# qe_sql-editor-tb-icon_zoom-area@2x.png
# wb_item_overlay_result@2x.png
# layers.png
# qe_main-tb-icon_open-sql-file.png
# qe_sql-editor-tb-icon_find@2x.png
# db.Schema.unloaded.side.16x16.png
# ps_switcher_default_hoover.png
# MySQL-WB-about-screen.png
# mini_error.png
# admin_export@2x.png
# tiny_undo.png
# qe_sql-editor-tb-icon_special-chars-off.png
# grt_dict.png
# arrow_up.png
# ps_switcher_custom_hoover@2x.png
# collapsing_panel_header_tab_right_flat.png
# collapsing_panel_minus_flat.png
# ps_switcher_disabled_off.png
# mysql-logo-57@2x.png
# record_del@2x.png
# Discard_16x16.png
# ps_switcher_text_dark@2x.png
# collapsing_panel_tab_left.png
# item_overlay_add@2x.png
# editor_breakpoint_hit.png
# title_dashboard.png
# dashboard_header_network_dark@2x.png
# task_checked.png
# snippet_css.png
# wb-backup-logo.png
# note.png
# db.RoutineGroup.48x48.png
# GrtObject.16x16.png
# workbench.physical.Model.48x48.png
# sybase_rdbms_info.xml
# snippet_php.png
# wb-toolbar_nav-back.png
# qe_sql-editor-tb-icon_zoom-out@2x.png
# admin_schema_management@2x.png
# admin_performance_reports@2x.png
# db.ForeignKey.16x16.png
# shell_snippets.py.txt
# db.Column.fk.11x11.png
# MySQLPlugin-16.png
# qe_main-tb-icon_add-table.png
# tiny_less_space.png
# magnify_region_dark.png
# dashboard_arrow_in_static.png
# task_disabled_mac.png
# wb_draw_rect.png
# Last_16x16.png
# workbench.physical.sybase.Model.48x48.png
# wb_tile_number_light.png
# tab.sqlquery.16x16.png
# qe_main-tb-icon_preferences.png
# Refresh_disabled_18x18.png
# zoom_reset.png
# tiny_new_diagram.png
# ps_switcher_text_light.png
# title_performance_reports.png
# db.Routine.many.32x32.png
# MySQLWBPlugin.icns
# qe_sql-editor-tb-icon_rollback@2x.png
# tiny_new_table.png
# snippet_insert.png
# mssql_rdbms_info.xml
# firewall-header.png
# record_sort_reset.png
# mysql-status-off.png
# collapsing_panel_header_tab_add.png
# db.RoutineGroup.add.48x48.png
# switcher_right_off.png
# debug_step.png
# admin_info_running.png
# dashboard_arrow_out_static.png
# db.Table.32x32.png
# routine_dark.png
# record_first.png
# ac_trigger.png
# qe_sql-editor-tb-icon_execute.png
# debug_pause.png
# mysql-status-off@2x.png
# qe_main-tb-icon_add-table_mac@2x.png
# record_autosize@2x.png
# item_overlay_delete@2x.png
# tiny_align_h_left2.png
# dashboard_header_innodb_dark.png
# collapsing_panel_plus_flat.png
# db.Trigger.side.16x16@2x.png
# db.DatatypeGroup.text.16x16.png
# mini_notice.png
# tab_icon_db.query.QueryBuffer_dark@2x.png
# tiny_rollback@2x.png
# admin_server_logs@2x.png
# mysql-status-separator@2x.png
# wb_item_overlay_inspector@2x.png
# db.mgmt.Connection.32x32.png
# wb_doc_sql.png
# collapsing_panel_minus.png
# qe_sql-editor-tb-icon_stop-on-error-off@2x.png
# output_type-formeditor@2x.png
# db.Schema.loading.side.16x16.png
# JS_Datatype_Number@2x.png
# db.Table.many.side.16x16.png
# wb_toolbar_pages_18x18.png
# title_performance_reports@2x.png
# qe_sql-editor-tb-icon_execute-current.png
# output_type-toggle-off@2x.png
# record_back@2x.png
# db.View.side.16x16@2x.png
# db.Index.side.16x16@2x.png
# qe_sql-editor-tb-icon_autocommit-off.png
# collapsing_panel_header_tab_separator.png
# snippet_clipboard.png
# admin_info_unknown@2x.png
# tiny_ruler.png
# ac_sysvar.png
# qe_main-tb-icon_add-view_mac.png
# busy_sidebar.png
# tiny_save.png
# admin_instrumentation_setup@2x.png
# workbench.physical.Layer.many.16x16.png
# MySQLWorkbench.icns
# qe_main-tb-icon_execute-sql-file_mac.png
# wb_tile_sakila_light.png
# task_checked_mac.png
# db.Table.24x24.png
# editor_statement.png
# db.Routine.add.16x16.png
# JS_Datatype_Bool@2x.png
# task_warning.png
# editor_current_pos.png
# properties.png
# db.mgmt.Connection.48x48.png
# big_switcher_no@2x.png
# dashboard_header_mysql_light@2x.png
# wb_item_overlay_result.png
# db.View.many.32x32.png
# dashboard_header_innodb_dark@2x.png
# wb_rel_11_nonid_dark.png
# sqlide_power_import_wizard.py
# ps_switcher_fully_on.png
# maintab_home_black.png
# db.DatatypeGroup.userdefined.16x16.png
# ac_keyword.png
# tiny_hidesidebar.png
# switcher_right_on.png
# migration_background.png
# tab_icon_db.query.QueryBuffer_light.png
# record_add.png
# wb_rel_11_nonid.png
# zoom_in.png
# wb_tile_network_dark.png
# db.Schema.many.16x16.png
# rel1n.png
# wb_note.png
# hand_dark.png
# Discard.png
# output_type-spacialview.png
# ac_uservar.png
# db.Table.48x48.png
# title_logs.png
# big_switcher_yes@2x.png
# qe_main-tb-icon_refresh-conn_mac.png
# wb_item_overlay_execute.png
# mini_warning.png
# tab_icon_administrator@2x.png
# wb_item_overlay_execute@2x.png
# sidebar_migration.png
# wb-toolbar_automatic-help-off@2x.png
# admin_connections.png
# wb_lock@2x.png
# db.Trigger.16x16.png
# tiny_redo.png
# message_warning.png
# wb_lock.png
# qe_sql-editor-tb-icon_word-wrap-off@2x.png
# wb_tile_folder_mini_light@2x.png
# Apply.png
# title_variables.png
# ps_easysetup_logo_enabled.png
# qe_main-tb-icon_refresh-conn_mac@2x.png
# JS_Datatype_Null.png
# EditorCollapsed.png
# collapsing_panel_grid_large_icons2.png
# switcher_left_off.png
# admin_dashboard@2x.png
# title_table_inspector.png
# qe_main-tb-icon_search_db_mac.png
# output_type-fieldtypes@2x.png
# ps_switcher_text_light@2x.png
# unknown.png
# record_export@2x.png
# editor_continue_on_error.png
# navigator_zoom_out.png
# admin_meb_backup@2x.png
# collapsing_panel_header_tab_middle_flat.png
# wb_item_overlay_editor.png
# admin_scripts@2x.png
# message_edit.png
# db.Schema.16x16.png
# MySQLPlugin-64.png
# debug_continue.png
# tiny_new_routine.png
# qe_sql-editor-tb-icon_special-chars-on.png
# admin_system_startup@2x.png
# admin_meb_restore.png
# ps_switcher_custom_on.png
# admin_server_logs.png
# admin_start_stop.png
# tiny_rollback.png
# record_fetch_prev.png
# change_forward.png
# ps_switcher_fully_off@2x.png
# wb_tile_time_light.png
# collapsing_panel_grid_small_icons2.png
# wb_db_table.png
# db.User.add.16x16.png
# tiny_rollback_disabled.png
# db.Column.16x16.png
# admin_audit_inspector@2x.png
# wb-toolbar_nav-forward.png
# switcher_bottom_on.png
# JS_Datatype_Date.png
# ps_switcher_disabled_on.png
# wb_item_overlay_autozoom.png
# title_export@2x.png
# tcp_utils.py
# change_alert_create.png
# collapsing_panel_grid_small_icons.png
# change_alert_drop.png
# snippet_del.png
# mysql-logo-00.png
# admin_info_stopped.png
# task_executing_mac.png
# qe_main-tb-icon_add-schema_mac.png
# admin_dashboard.png
# output_type-fieldtypes.png
# qe_sql-editor-explain-tb-overview@2x.png
# qe_main-tb-sep.png
# db.View.16x16.png
# show_whitespace.png
# db.Column.pk.side.16x16.png
# collapsing_panel_header_tab_separator_flat.png
# record_discard.png
# output_type-explaindata@2x.png
# search_icon.png
# WBSQLQueryPanel.nib
# qe_main-tb-icon_add-table_mac.png
# db.ForeignKey.side.16x16.png
# db.View.broken.side.16x16@2x.png
# db.Routine.editor.48x48.png
# tiny_align_h_middle2.png
# wb-toolbar_automatic-help-off.png
# MySQLPlugin-48.png
# title_startup@2x.png
# JS_Datatype_Bin.png
# record_fetch_next.png
# workbench.Document.16x16.png
# db.ForeignKey.side.16x16@2x.png
# title_dashboard@2x.png
# title_users.png
# note_dark.png
# wb_tile_more_dark.png
# db.View.many.side.16x16@2x.png
# switcher_left_on.png
# admin_manage_privs@2x.png
# workbench.physical.Diagram.add.16x16.png
# refresh_sidebar_mac.png
# mysql-status-on@2x.png
# ps_switcher_legend.png
# db.Schema.loading.side.16x16@2x.png
# workbench.logical.Diagram.48x48.png
# DotDisabled.png
# admin_server_status@2x.png
# MySQLPlugin-128.png
# home_screen_close_light@2x.png
# ac_engine.png
# workbench.physical.Diagram.48x48.png
# qe_sql-editor-tb-icon_rollback.png
# title_variables@2x.png
# JS_Datatype_Array.png
# output_type-querystats.png
# db.Column.pkfk.16x16.png
# GrtStoredNote.48x48.png
# change_ignore.png
# ac_collation.png
# ps_switcher_custom_hoover.png
# db.Table.editor.24x24.png
# wb_close.png
# debug_stop.png
# maintab_home_white@2x.png
# output_type-explaindata.png
# tab_icon_editor@2x.png
# tiny_align_v_bottom2.png
# qe_main-tb-icon_preferences_mac.png
# collapsing_panel_grid_details.png
# ac_function.png
# qe_sql-editor-tb-icon_special-chars-on@2x.png
# wb_tile_folder_mini_dark@2x.png
# output_type-executionplan.png
# qe_sql-editor-tb-icon_beautifier_current.png
# workbench.physical.sqlite.Model.48x48.png
# qe_sql-editor-tb-icon_explain.png
# db.Column.pkai.11x11.png
# db.Routine.16x16.png
# admin_info_stopped@2x.png
# collapsing_panel_grid_details2.png
# sidebar_migration@2x.png
# db.User.16x16.png
# JS_Datatype_Array@2x.png
# qe_sql-editor-tb-icon_special-chars-off@2x.png
# refresh_sidebar.png
# tiny_open.png
# admin_option_file.png
# workbench.physical.TableFigure.16x16.png
# db.Table.editor.48x48.png
# ac_charset.png
# admin_restore_data@2x.png
# workbench.physical.mysql.Model.48x48.png
# editor_breakpoint.png
# tiny_refresh.png
# switcher_bottom_off@2x.png
# wb_image.png
# wb_item_overlay_autozoom@2x.png
# mysql-logo-51@2x.png
# db.Table.many.32x32.png
# db.Routine.many.side.16x16.png
# qe_sql-editor-resultset-tb-pinned@2x.png
# wb_tile_folder_mini_dark.png
# hand.png
# qe_sql-editor-tb-icon_zoom-reset.png
# rubber_dark.png
# grt_function.png
# GrtObject.add.32x32.png
# snippet_mwb.png
# wb_magnifier.png
# tree_expanded.png
# task_warning_mac.png
# task_disabled.png
# section_expanded.png
# db.View.add.16x16.png
# tiny_saveas.png
# workbench.logical.Model.48x48.png
# background.png
# wb_tile_more_light.png
# wb_tile_folder.png
# qe_sql-editor-resultset-tb-pin@2x.png
# header_bar_blue.png
# db.Column.pkfk.11x11.png
# migration_title.png
# wb_item_overlay_editor@2x.png
# qe_sql-editor-tb-icon_zoom-in.png
# task_executing.png
# db.Column.side.16x16@2x.png
# workbench.physical.RoutineGroupFigure.16x16.png
# db.Schema.side.16x16@2x.png
# title_users@2x.png
# wb_rel_nm.png
# tiny_new.png
# qe_main-tb-icon_add-routine.png
# db.Table.many.16x16.png
# query_continue_on_error.png
# qe_main-tb-icon_add-function_mac.png
# db.Role.48x48.png
# busy_sidebar_mac.png
# clear_output.png
# README.md
# tiny_align_h_right.png
# GrtObject.add.16x16.png
# snippet_use.png
# wb_tile_time_dark.png
# wb-toolbar_automatic-help-on.png
# qe_sql-editor-tb-icon_zoom-auto@2x.png
# magnify_region.png
# workbench.physical.Layer.24x24.png
# JS_Datatype_String.png
# wb_rel_1n_nonid.png
# dashboard_header_mysql_light.png
# history.png
# db.Column.many.side.16x16.png
# object_inspector_mac@2x.png
# record_sort_desc.png
# db.Trigger.many.side.16x16.png
# item_overlay_delete.png
# task_unchecked_mac.png
# qe_main-tb-icon_execute-sql-file.png
# ps_easysetup_logo@2x.png
# qe_sql-editor-tb-icon_stop-on-error-on@2x.png
# grt_object.png
# mysql-logo-58@2x.png
# qe_main-tb-icon_search_db_mac@2x.png
# rel11.png
# ps_switcher_disabled_on@2x.png
# wb_draw_line.png
# admin_config_wizard.png
# db.Role.add.48x48.png
# tiny_lock.png
# record_back.png
# admin_info_offline.png
# collapsing_panel_header_tab_left_flat.png
# qe_main-tb-icon_add-routine_mac.png
# qe_sql-editor-tb-icon_find.png
# item_overlay_add.png
# wb_tile_sakila_dark.png
# ps_switcher_custom_on@2x.png
# admin_start_stop@2x.png
# wb_rel_nm_dark.png
# layer.png
# zoom_out.png
# qe_main-tb-icon_add-function.png
# workbench.physical.oracle.Model.48x48.png
# sidebar_launchers.png
# qe_main-tb-icon_add-function_mac@2x.png
# workbench.Document.32x32.png
# admin_meb_restore@2x.png
# record_first@2x.png
# navigator_zoom_in.png
# collapsing_panel_grid_bg.png
# migration_check_done.png
# dashboard_header_network_light.png
# wb_tab_close_dark.png
# separator_vertical.png
# debug_step_out.png
# db.Routine.side.16x16.png
# db.mgmt.Connection.add.48x48.png
# routine.png
# wb_tile_open_dark.png
# record_save.png
# DotRed.png
# wb_perform_config.png
# search_clear.png
# db.mgmt.ServerInstance.manage.48x48.png
# mini_ok.png
# db.View.broken.side.16x16.png
# qe_sql-editor-tb-icon_execute@2x.png
# wb-backup-logo-small.png
# collapsing_panel_header_tab_middle.png
# wb_tab_close_light.png
# qe_main-tb-icon_preferences_mac@2x.png
# output_type-item_selected@2x.png
# tab_icon_db.query.QueryBuffer_dark.png
# admin_restore_data.png
# message_error.png
# db.Table.add.16x16.png
# migration_logo.png
# warning_icon.png
# dialog_input.png
# record_import.png
# qe_sql-editor-tb-icon_autocommit-on@2x.png
# wb_tile_schema_dark@2x.png
# output_type-spacialview@2x.png
# qe_sql-editor-tb-icon_zoom-jump@2x.png
# admin_manage_exported.png
# sidebar_modeling@2x.png
# tiny_new_view.png
# db.Column.pkai.16x16.png
# wb_draw_ellipse.png
# grt_module.png
# wb_tile_folder_mini_light.png
# db.Table.side.16x16@2x.png
# qe_sql-editor-tb-icon_commit.png
# title_export.png
# db.View.many.side.16x16.png
# ps_switcher_custom_off@2x.png
# tiny_new_script.png
# collapsing_panel_header_bg_flat.png
# wb-sidebar-refresh.png
# datatype_mapping_editor.py
# db.Schema.32x32.png
# qe_sql-editor-tb-icon_autocommit-off@2x.png
# qe_main-tb-icon_add-view_mac@2x.png
# collapsing_panel_tab_right.png
# ac_operator.png
# separator_vertical@2x.png
# tiny_load.png
# GrtObject.48x48.png
# db.RoutineGroup.16x16.png
# MySQLWorkbenchDoc.icns
# title_logs@2x.png
# wb_rel_1n_pick.png
# collapsing_panel_bg.png
# qe_main-tb-icon_execute-sql-file_mac@2x.png
# workbench.physical.Model.16x16.png
# change_nothing.png
# EditorExpanded.png
# workbench.logical.Diagram.add.48x48.png
# MySQL-WB-about-screen@2x.png
# home_screen_close_dark@2x.png
# admin_status_vars.png
# MySQLPlugin-256.png
# opts.py
# message_wb_bug.png
# note.128x128.png
# qe_sql-editor-resultset-tb-pin.png
# qe_sql-editor-tb-icon_stop@2x.png
# db.Column.many.side.16x16@2x.png
# tiny_loadsql.png
# ac_column.png
# wb-backup-logo-small@2x.png
# record_fetch_all@2x.png
# wb_tile_schema_light@2x.png
# GrtObject.24x24.png
# comment.png
# record_add@2x.png
# edit_table_templates.png
# sidebar_launchers@2x.png
# layer_dark.png
# view.png
# table_dark.png
# snippet_sql.png
# ps_switcher_fully_hoover.png
# wb-toolbar_automatic-help-on@2x.png
# qe_main-tb-icon_add-schema_mac@2x.png
# tiny_align_v_top.png
# record_next.png
# JS_Datatype_Null@2x.png
# view_dark.png
# sidebar_wb.png
# record_edit.png
# image_dark.png
# rel1n_dark.png
# qe_main-tb-icon_add-schema.png
# db.Routine.64x64.png
# output_type-resultset@2x.png
# wb-toolbar_nav-forward@2x.png
# db.mgmt.ServerInstance.48x48.png
# admin_scripts.png
# EmbedableFindPane.nib
# rel11_dark.png
# ps_easysetup_logo_enabled@2x.png
# qe_sql-editor-resultset-tb-pinned.png
# record_import@2x.png
# tiny_align_h_middle.png
# workbench.physical.ViewFigure.16x16.png
# db.Column.11x11.png
# JS_Datatype_Object.png
# db.Schema.many.32x32.png
# migration_check_point.png
# collapsing_panel_header_tab_del.png
# sidebar_modeling.png
# db.User.editor.48x48.png
# db.Script.add.48x48.png
# title_backup.png
# title_instrumentation_setup.png
# ac_schema.png
# wb_tile_plus_light.png
# admin_add_user.png
# db.ForeignKey.many.side.16x16.png
# qe_sql-editor-tb-icon_word-wrap-on.png
# wb-toolbar_manual-help.png
# db.RoutineGroup.add.16x16.png
# search_doc_action.png
# admin_info_unknown.png
# db.DatatypeGroup.datetime.16x16.png
# admin_info_offline@2x.png
# db.View.64x64.png
# title_import@2x.png
# audit_log.png
# ps_overview@2x.png
# admin_audit_inspector.png
# switcher_left_on@2x.png
# title_instrumentation_setup@2x.png
# wb_tile_plus_dark.png
# statusbar_output.png
# WBModelDiagram.nib
# mysql-logo-56@2x.png
# workbench.model.ImageFigure.16x16.png
# notifications.py
# tiny_align_v_middle.png
# db.DatatypeGroup.numeric.16x16.png
# JS_Datatype_ObjectId@2x.png
# ac_logfilegroup.png
# record_fetch_prev@2x.png
# wb_db_view.png
# First_16x16.png
# wb_doc_model@2x.png
# JS_Datatype_ObjectId.png
# db.View.many.16x16.png
# qe_sql-editor-tb-icon_word-wrap-off.png
# admin_config_wizard@2x.png
# wb_tile_network_light.png
# workbench.model.NoteFigure.16x16.png
# db.mgmt.Connection.manage.48x48.png
# change_tracker.py
# header_bar_orange.png
# db.mgmt.Connection.16x16.png
# tab_icon_db.query.QueryBuffer_light@2x.png
# admin_manage_exported@2x.png
# db.Column.fk.side.16x16.png
# change_backward.png
# collapsing_panel_header_bg.png
# output_type-querystats@2x.png
# mini_edit.png
# user_datatypes.png
# mysql-logo-50.png
# search_sidebar.png
# ps_switcher_default_on.png
# db.Routine.add.48x48.png
# big_switcher_no.png
# change_alert_thin.png
# qe_sql-editor-tb-icon_beautifier_current@2x.png
# maintab_home_white.png
# db.Schema.add.32x32.png
# tab_icon_editor.png
# qe_sql-editor-tb-icon_commit@2x.png
# tiny_align_h_left.png
# tiny_new_schema.png
# db.Table.side.16x16.png
# mysql_system_status_rmt.vbs
# wb_rubber.png
# admin_add_user@2x.png
# relnm.png
# Apply_16x16.png
# message_wb_wait.png
# MySQLPlugin-24.png
# admin_schema_management.png
# db.Column.fk.16x16.png
# db.DatatypeGroup.blob.16x16.png
# ac_tablespace.png
# wait_panel_cancel_button.png
# ps_switcher_default_on@2x.png
# wb_tile_user_dark.png
# output_type-item_selected.png
# Refresh_18x18.png
# WBModelOverview.nib
# db.Table.16x16.png
# output_type-toggle-off.png
# wb_tile_time_dark@2x.png
# sakila.png
# admin_connections@2x.png
# collapsing_panel_tab_middle.png
# ac_user.png
# edit.png
# wb_tab_close_dark@2x.png
# message_confirm.png
# wb_rel_11.png
# workbench.physical.db2.Model.48x48.png
# tiny_refresh_plugins.png
# Firewall_reports.png
# qe_sql-editor-tb-icon_zoom-jump.png
# migration_check_open.png
# mysql-logo-51.png
# ac_index.png
# title_connections.png
# qe_sql-editor-tb-icon_open.png
# qe_sql-editor-tb-icon_zoom-reset@2x.png
# tiny_grid.png
# qe_sql-editor-tb-icon_beautifier.png
# admin_export.png
# db.Role.editor.48x48.png
# qe_sql-editor-tb-icon_execute-current@2x.png
# record_last@2x.png
# wb_doc_model.png
# title_startup.png
# db.Table.many.side.16x16@2x.png
# JS_Datatype_String@2x.png
# tiny_grtshell.png
# tiny_gridview.png
# wb_tile_schema_light.png
# dashboard_separator@2x.png
# mysql-status-on.png
# wb-toolbar_nav-back@2x.png
# ps_switcher_fully_off.png
# tiny_search.png
# grt_struct.png
# editor_error.png
# tiny_align_v_middle2.png
# ps_switcher_custom_off.png
# ac_routine.png
# db.Routine.many.16x16.png
# wb_tile_time_light@2x.png
# qe_sql-editor-tb-icon_stop-on-error-off.png
# qe_sql-editor-tb-icon_zoom-area.png
# collapsing_panel_header_shadow.png
# License.txt
# admin_firewall.png
# db.Schema.24x24.png
# JS_Datatype_Date@2x.png
# title_schema_inspector@2x.png
# debug_step_into.png
# record_del.png
# mysql_system_status.vbs
# admin_firewall@2x.png
# MySQLPlugin-32.png
# qe_main-tb-icon_add-sql-editor.png
# Close_16x16.png
# qe_sql-editor-tb-icon_zoom-auto.png
# grt_list.png
# collapsing_panel_header_tab_left.png
# qe_sql-editor-tb-icon_open@2x.png
# title_restore.png
# record_wrap_vertical.png
# field_overlay_null.png
# db.Index.16x16.png
# title_restore@2x.png
# tab.overview.home.16x16.png
# db.DatatypeGroup.geo.16x16.png
# dashboard_separator.png
# db.User.add.48x48.png
# wb_draw_polygon.png
# tiny_new_doc.png
# relnm_dark.png
# collapsing_panel_plus.png
# GrtStoredNote.add.48x48.png
# tab_icon_administrator.png
# collapsing_panel_header_tab_del2.png
# GrtObject.32x32.png
# record_refresh.png
# title_backup@2x.png
# field_overlay_blob.png
# record_last.png
# wb_tile_open_light.png
# db.View.editor.48x48.png
# show_eof.png
# title_options.png
# task_error_mac.png
# output_type-resultset.png
# wb-sidebar-refresh@2x.png
# wb-toolbar_manual-help@2x.png
# mysql-logo-50@2x.png
# collapsing_panel_header_tab_right.png
# title_options@2x.png
# mysql-logo-56.png
# wb_draw_freehand.png
# record_fetch_all.png
# db.Routine.side.16x16@2x.png
# options-horizontal-separator.png
# db.Trigger.many.side.16x16@2x.png
# task_error.png
# wb_rel_11_dark.png
# qe_sql-editor-tb-icon_autocommit-on.png
# wb_tile_schema_dark.png
# small_toolbar_bg.png
# db.Script.48x48.png
# HUDPanel.nib
# ps_switcher_legend@2x.png
# ps_overview.png
# title_schema_inspector.png
# DotBlue.png
# db.Index.many.side.16x16.png
# record_autosize.png
# db.View.48x48.png
# admin_system_startup.png
# grt_simple_type.png
# db.Column.fknn.11x11.png
# workbench.physical.mssql.Model.48x48.png
# admin_performance_reports.png
# tab_icon_plugin.png
# table.png
# db.Schema.unloaded.side.16x16@2x.png
# maintab_home_black@2x.png
# background_stripes_light.png
# tiny_refresh@2x.png
# wb_tile_user_light.png
# db.Column.pk.16x16.png
# record_export.png
# db.Schema.editor.48x48.png
# qe_main-tb-icon_search_db.png
# db.Routine.many.side.16x16@2x.png
# workbench.logical.Diagram.16x16.png
# arrow_down.png
# task_unchecked.png
# query_stop_on_error.png
# wb_arrow.png
# ps_switcher_fully_hoover@2x.png
# workbench.physical.Diagram.16x16.png
# migration_check_current.png
# wb_tile_manage_light.png
# statusbar_separator.png
# db.View.24x24.png
# qe_sql-editor-tb-icon_word-wrap-on@2x.png
# migration.png
# ps_switcher_default_off@2x.png
# db.Column.nn.11x11.png
# workbench.physical.Diagram.add.48x48.png
# dashboard_header_mysql_dark@2x.png
# tiny_savesql.png
# qe_main-tb-icon_add-view.png
# ps_switcher_fully_on@2x.png
# title_import.png
# workbench.Document.48x48.png
# admin_server_status.png
# mysql-logo-57.png
# admin_option_file@2x.png
# output_type-toggle-on.png
# JS_Datatype_Object@2x.png
# sidebar_wb@2x.png
# mysql-logo-55.png
# WizardWindow.nib
# db.Column.side.16x16.png
# db.User.48x48.png
# qe_sql-editor-tb-icon_save@2x.png
# uncheck.png
# collapsing_panel_header_tab_add2.png
# db.ForeignKey.many.side.16x16@2x.png
# qe_main-tb-icon_open-sql-file_mac@2x.png
# db.Routine.48x48.png
# admin_status_vars@2x.png
# qe_sql-editor-tb-icon_save.png
# tree_collapsed.png
# header_bar_gray.png
# tiny_align_h_right2.png
# schemata.png
# db.Trigger.side.16x16.png
# output_type-executionplan@2x.png
# section_unexpanded.png
# grt.png
# dashboard_header_innodb_light@2x.png
# qe_sql-editor-tb-icon_zoom-center@2x.png
# ac_event.png
# big_switcher_yes.png
# image.png
# JS_Datatype_Bool.png
# admin_firewall_reports.png
# admin_info_running@2x.png
# db.View.add.48x48.png
# ps_switcher_disabled_hoover@2x.png
# wb-backup-logo@2x.png
# qe_main-tb-icon_add-routine_mac@2x.png
# admin_instrumentation_setup.png
# workbench.logical.Model.16x16.png
# db.View.side.16x16.png
# tiny_align_v_top2.png
# qe_sql-editor-tb-icon_beautifier@2x.png
# db.Index.side.16x16.png
# mysqlwbmeb.py
# record_next@2x.png
# db.Routine.24x24.png
# qe_main-tb-icon_refresh-conn.png
# db.Column.fk.side.16x16@2x.png
# sqlide_power_import_export_be.py
# wb_rel_1n_dark.png
# tab.diagram.16x16.png
# qe_sql-editor-tb-icon_zoom-out.png
# GrtObject.many_32x32.png
# ps_switcher_disabled_hoover.png
# output_type-toggle-on@2x.png
# qe_main-tb-icon_add-sql-editor_mac.png
# snippet_add.png
# firewall-header@2x.png
# page_restore@2x.png
# admin_manage_privs.png
# workbench.physical.mysql.Model.16x16.png
# qe_sql-editor-tb-icon_zoom-center.png
# wb_tile_manage_dark.png
# wb_rel_1n_nonid_dark.png
# DB Management.txt
# SQL DDL Statements.txt
# SQL DML Statements.txt
# InfoPlist.strings
# db_sybase_re_grt.py
# sqlide_import_spatial.py
# wb_admin_config_file_ui.py
# performance_charting.py
# db_sqlanywhere_migration_grt.py
# db_mssql_grt.py
# db_sybase_migration_grt.py
# sqlide_power_export_wizard.py
# table_templates.py
# wb_server_control.py
# sqlide_grt.py
# migration_main.py
# wb_common.py
# wb_admin_connections.py
# migration_data_transfer.py
# db_copy_overview.py
# migration_schema_selection.py
# wb_admin_grt.py
# wb_admin_main.py
# wb_admin_performance_dashboard.py
# run_script.py
# wb_admin_monitor.py
# db_copy_source_target.py
# db_mysql_migration_grt.py
# sqlide_schematree_ext.py
# SQLEXT.py
# wba_ssh_ui.py
# explain_renderer.py
# code_utils_grt.py
# wb_log_reader.py
# sqlanydbwrapper.py
# wb_admin_server_status.py
# sqlide_power_import_wizard.py
# db_mysql_fe_grt.py
# migration_bulk_copy_data.py
# wb_admin_variable_list.py
# migration_toolbars.py
# wb_admin_variables.py
# db_generic_re_grt.py
# wb_admin_control.py
# db_postgresql_migration_grt.py
# migration_object_editing.py
# db_copy_progress.py
# migration_schema_mappings.py
# wb_catalog_utils.py
# sqlide_tableman_ext.py
# wb_admin_user_privileges.py
# wb_admin_perfschema_instrumentation_be.py
# wb_admin_logs.py
# sqlide_catalogman_ext.py
# wb_admin_perfschema_reports.py
# db_sql92_migration_grt.py
# wb_utils_grt.py
# db_mssql_migration_grt.py
# wb_admin_utils.py
# db_mysql_re_grt.py
# wb_admin_config_file_be.py
# wb_admin_perfschema_instrumentation.py
# wb_execute_window.py
# migration_summary.py
# wb_admin_configuration_startup.py
# wb_admin_security_be.py
# sql_reformatter.py
# wb_admin_export_options.py
# migration_project_management.py
# wb_model_utils.py
# db_copy_main.py
# wb_dev_utils_grt.py
# migration_schema_creation.py
# wb_admin_export.py
# datatype_mapping_editor.py
# opts.py
# migration_ui_style.py
# db_sqlanywhere_re_grt.py
# wb_query_analysis_grt.py
# db_copy_report.py
# text_output.py
# db_sqlite_re_grt.py
# db_generic_migration_grt.py
# migration_object_selection.py
# migration_source_selection.py
# db_sqlite_migration_grt.py
# db_sql92_re_grt.py
# migration_object_migration.py
# table_utils_grt.py
# sqlide_resultset_ext.py
# migration_grt.py
# migration.py
# text_grt.py
# DataMigrator.py
# db_copy_grt.py
# db_copy_schema_selection.py
# wb_admin_security.py
# db_postgresql_re_grt.py
# optimizer_trace_renderer.py
# wb_admin_perfschema.py
# wba_monitor_be.py
# wb_server_management.py
# sqlide_power_import_export_be.py
# migration_overview.py
# wb_admin_ui_profile.py
# Windows_x64_(MySQL_x86_zip_Package).xml
# Ubuntu_Linux_(Vendor_Package).xml
# CMakeLists.txt
# Ubuntu_Linux_(MySQL_Package).xml
# MySQL_Sandbox_Linux(MySQL_tar_package).xml
# Fedora_Linux_(Vendor_Package).xml
# MySQL_Sandbox_MacOS(MySQL_tar_package).xml
# Oracle_Linux_7_(MySQL_Package).xml
# Oracle_Linux_6_(MySQL_Package).xml
# SLES_(MySQL_Package).xml
# Fedora_Linux_24_(Vendor_Package).xml
# RHEL_7_(MySQL_Package).xml
# macOS_(MySQL_Package).xml
# OpenSolaris_(MySQL_Package).xml
# Generic_Linux_(MySQL_tar_package).xml
# Windows_(MySQL_5.7_Installer_Package).xml
# Windows_(MySQL_5.6_Installer_Package).xml
# Fedora_Linux_(MySQL_Package).xml
# RHEL_(MySQL_Package).xml
# Fedora_Linux_25_(Vendor_Package).xml
# Windows_(MySQL_8.0_Installer_Package).xml
# FreeBSD_(MySQL_Package).xml
# Ubuntu_Linux_(sysvinit,_MySQL_Package).xml
# Ubuntu_Linux_(sysvinit,_Vendor_Package).xml
# CentOS_7_(MySQL_Package).xml
# Windows_(MySQL_5.5_Installer_Package).xml
# Linux_(Custom).xml
# wb.py
# _cairo.so
# pyodbc.cpython-38-darwin.so
# mforms.py
# cairo.py
# db_utils.py
# _mforms.so
# grt_python_debugger.py
# mysqlwbmeb.py
# plugins.py
# os_utils.py
# client_utils.py
# CMakeLists.txt
# wizard_progress_page_widget.py
# log.py
# ui.py
# db_driver.py
# tcp_utils.py
# __init__.py
# database_schema_selector_widget.py
# utils.py
# database_object_selector_widget.py
# wizard_form.py
# template.py
# exceptions.py
# notifications.py
# change_tracker.py
# db_utils.py
# wizard_page_widget.py
# profiling.py
# database_object_selector.png
# schema_selection_widget.png
# __init__.py
# charting.py
# cairo_utils.py
# canvas.py
# MainWindow.nib
# PluginEditorWindow.nib
# MainMenu.nib
# PageSetup.nib
# IconCollectionView.nib
# DiagramOptions.nib
# sys_reports.js
# LICENSE
# after_setup.sql
# generate_sql_file.sh
# README.md
# sys_57.sql
# sys_56.sql
# before_setup.sql
# ps_setup_show_disabled.sql
# ps_setup_reset_to_default.sql
# ps_setup_reload_saved.sql
# ps_setup_enable_consumers.sql
# ps_setup_disable_consumers.sql
# ps_setup_save.sql
# create_synonym_db.sql
# ps_statement_avg_latency_histogram.sql
# ps_setup_enable_consumer.sql
# ps_setup_reset_to_default_57_after.sql
# ps_setup_enable_background_threads.sql
# ps_setup_show_disabled_consumers.sql
# ps_setup_reset_to_default_57_before.sql
# ps_setup_enable_instrument.sql
# ps_setup_show_enabled_consumers.sql
# ps_trace_thread.sql
# ps_setup_reset_to_default_57.sql
# ps_setup_show_enabled_instruments.sql
# ps_setup_show_disabled_instruments.sql
# ps_setup_disable_consumer.sql
# ps_setup_show_enabled.sql
# ps_truncate_all_tables.sql
# ps_trace_statement_digest.sql
# ps_setup_disable_instrument.sql
# ps_setup_enable_thread.sql
# ps_setup_disable_thread.sql
# ps_setup_disable_background_threads.sql
# sys_config.sql
# sys_config_data.sql
# sys_config_update_set_user.sql
# sys_config_insert_set_user.sql
# ps_is_account_enabled_57.sql
# ps_is_thread_instrumented.sql
# sys_get_config.sql
# format_statement.sql
# format_time.sql
# ps_is_consumer_enabled.sql
# ps_is_account_enabled.sql
# extract_table_from_file_name.sql
# format_path.sql
# ps_thread_id.sql
# ps_is_instrument_default_timed.sql
# extract_schema_from_file_name.sql
# format_bytes.sql
# ps_thread_stack.sql
# ps_is_instrument_default_enabled.sql
# x_io_global_by_wait_by_latency.sql
# x_memory_by_host_by_current_bytes.sql
# x_memory_global_by_current_bytes.sql
# x_statements_with_temp_tables.sql
# x_host_summary_by_statement_latency.sql
# io_by_thread_by_latency.sql
# schema_unused_indexes.sql
# x_statement_analysis.sql
# x_latest_file_io.sql
# x_io_global_by_file_by_latency.sql
# x_io_by_thread_by_latency.sql
# processlist_57.sql
# memory_by_user_by_current_bytes.sql
# x_user_summary.sql
# x_statements_with_errors_or_warnings.sql
# x_memory_by_thread_by_current_bytes.sql
# ...
# db_sql92_re_grt.cpython-38.pyc
# migration_grt.cpython-38.pyc
# sql_reformatter.cpython-38.pyc
# sqlide_power_import_wizard.cpython-38.pyc
# wb_admin_perfschema_instrumentation_be.cpython-38.pyc
# wb_log_reader.cpython-38.pyc
# wb_server_management.cpython-38.pyc
# wb_admin_export.cpython-38.pyc
# wb_admin_variable_list.cpython-38.pyc
# db_sql92_migration_grt.cpython-38.pyc
# migration_schema_selection.cpython-38.pyc
# wb_common.cpython-38.pyc
# wb_server_control.cpython-38.pyc
# wb_admin_configuration_startup.cpython-38.pyc
# run_script.cpython-38.pyc
# migration_project_management.cpython-38.pyc
# text_grt.cpython-38.pyc
# sqlide_tableman_ext.cpython-38.pyc
# sqlide_grt.cpython-38.pyc
# migration_toolbars.cpython-38.pyc
# migration_main.cpython-38.pyc
# sqlide_resultset_ext.cpython-38.pyc
# table_utils_grt.cpython-38.pyc
# db_copy_overview.cpython-38.pyc
# wb_admin_grt.cpython-38.pyc
# migration_object_editing.cpython-38.pyc
# wba_ssh_ui.cpython-38.pyc
# db_mssql_migration_grt.cpython-38.pyc
# text_output.cpython-38.pyc
# migration.cpython-38.pyc
# db_sqlite_migration_grt.cpython-38.pyc
# wb_admin_perfschema_reports.cpython-38.pyc
# opts.cpython-38.pyc
# db_copy_source_target.cpython-38.pyc
# wb_admin_config_file_ui.cpython-38.pyc
# db_sybase_re_grt.cpython-38.pyc
# wb_admin_monitor.cpython-38.pyc
# migration_object_migration.cpython-38.pyc
# wb_admin_control.cpython-38.pyc
# wb_admin_export_options.cpython-38.pyc
# db_postgresql_re_grt.cpython-38.pyc
# migration_summary.cpython-38.pyc
# db_sqlanywhere_migration_grt.cpython-38.pyc
# sqlide_import_spatial.cpython-38.pyc
# table_templates.cpython-38.pyc
# db_sqlanywhere_re_grt.cpython-38.pyc
# wb_utils_grt.cpython-38.pyc
# db_copy_main.cpython-38.pyc
# db_sybase_migration_grt.cpython-38.pyc
# wb_admin_security_be.cpython-38.pyc
# db_copy_schema_selection.cpython-38.pyc
# wba_monitor_be.cpython-38.pyc
# wb_admin_security.cpython-38.pyc
# migration_bulk_copy_data.cpython-38.pyc
# db_generic_re_grt.cpython-38.pyc
# DataMigrator.cpython-38.pyc
# db_mysql_fe_grt.cpython-38.pyc
# wb_dev_utils_grt.cpython-38.pyc
# migration_overview.cpython-38.pyc
# db_copy_report.cpython-38.pyc
# sqlide_catalogman_ext.cpython-38.pyc
# db_mssql_grt.cpython-38.pyc
# wb_admin_connections.cpython-38.pyc
# migration_object_selection.cpython-38.pyc
# migration_data_transfer.cpython-38.pyc
# wb_catalog_utils.cpython-38.pyc
# wb_admin_perfschema.cpython-38.pyc
# migration_ui_style.cpython-38.pyc
# wb_admin_performance_dashboard.cpython-38.pyc
# db_mysql_re_grt.cpython-38.pyc
# SQLEXT.cpython-38.pyc
# migration_schema_creation.cpython-38.pyc
# db_mysql_migration_grt.cpython-38.pyc
# db_generic_migration_grt.cpython-38.pyc
# db_postgresql_migration_grt.cpython-38.pyc
# sqlide_power_import_export_be.cpython-38.pyc
# db_copy_progress.cpython-38.pyc
# sqlide_power_export_wizard.cpython-38.pyc
# db_copy_grt.cpython-38.pyc
# wb_admin_server_status.cpython-38.pyc
# wb_admin_utils.cpython-38.pyc
# wb_admin_variables.cpython-38.pyc
# wb_admin_main.cpython-38.pyc
# mforms.cpython-38.pyc
# cairo.cpython-38.pyc
# wb.cpython-38.pyc
# __init__.cpython-38.pyc
# database_schema_selector_widget.cpython-38.pyc
# db_driver.cpython-38.pyc
# os_utils.cpython-38.pyc
# ui.cpython-38.pyc
# utils.cpython-38.pyc
# database_object_selector_widget.cpython-38.pyc
# client_utils.cpython-38.pyc
# log.cpython-38.pyc
# wizard_progress_page_widget.cpython-38.pyc
# template.cpython-38.pyc
# tcp_utils.cpython-38.pyc
# change_tracker.cpython-38.pyc
# wizard_page_widget.cpython-38.pyc
# db_utils.cpython-38.pyc
# plugins.cpython-38.pyc
# exceptions.cpython-38.pyc
# notifications.cpython-38.pyc
# wizard_form.cpython-38.pyc
# __init__.cpython-38.pyc
# charting.cpython-38.pyc
# cairo_utils.cpython-38.pyc
# canvas.cpython-38.pyc
# site.cpython-38.pyc
# tempfile.cpython-38.pyc
# operator.cpython-38.pyc
# reprlib.cpython-38.pyc
# stat.cpython-38.pyc
# shlex.cpython-38.pyc
# string.cpython-38.pyc
# base64.cpython-38.pyc
# dis.cpython-38.pyc
# queue.cpython-38.pyc
# lzma.cpython-38.pyc
# random.cpython-38.pyc
# socketserver.cpython-38.pyc
# _sitebuiltins.cpython-38.pyc
# sre_compile.cpython-38.pyc
# io.cpython-38.pyc
# functools.cpython-38.pyc
# pickle.cpython-38.pyc
# re.cpython-38.pyc
# platform.cpython-38.pyc
# pprint.cpython-38.pyc
# copyreg.cpython-38.pyc
# genericpath.cpython-38.pyc
# fnmatch.cpython-38.pyc
# warnings.cpython-38.pyc
# abc.cpython-38.pyc
# enum.cpython-38.pyc
# bisect.cpython-38.pyc
# subprocess.cpython-38.pyc
# copy.cpython-38.pyc
# selectors.cpython-38.pyc
# _bootlocale.cpython-38.pyc
# locale.cpython-38.pyc
# opcode.cpython-38.pyc
# sre_parse.cpython-38.pyc
# posixpath.cpython-38.pyc
# traceback.cpython-38.pyc
# types.cpython-38.pyc
# weakref.cpython-38.pyc
# csv.cpython-38.pyc
# signal.cpython-38.pyc
# socket.cpython-38.pyc
# contextlib.cpython-38.pyc
# tokenize.cpython-38.pyc
# pipes.cpython-38.pyc
# difflib.cpython-38.pyc
# os.cpython-38.pyc
# linecache.cpython-38.pyc
# _compat_pickle.cpython-38.pyc
# _collections_abc.cpython-38.pyc
# sre_constants.cpython-38.pyc
# keyword.cpython-38.pyc
# heapq.cpython-38.pyc
# token.cpython-38.pyc
# _compression.cpython-38.pyc
# getpass.cpython-38.pyc
# _weakrefset.cpython-38.pyc
# shutil.cpython-38.pyc
# datetime.cpython-38.pyc
# zipfile.cpython-38.pyc
# bz2.cpython-38.pyc
# struct.cpython-38.pyc
# ntpath.cpython-38.pyc
# codecs.cpython-38.pyc
# calendar.cpython-38.pyc
# inspect.cpython-38.pyc
# threading.cpython-38.pyc
# aliases.cpython-38.pyc
# __init__.cpython-38.pyc
# cp437.cpython-38.pyc
# latin_1.cpython-38.pyc
# utf_8.cpython-38.pyc
# ascii.cpython-38.pyc
# __init__.cpython-38.pyc
# _endian.cpython-38.pyc
# __init__.cpython-38.pyc
# context.cpython-38.pyc
# process.cpython-38.pyc
# reduction.cpython-38.pyc
# __init__.cpython-38.pyc
# decoder.cpython-38.pyc
# encoder.cpython-38.pyc
# scanner.cpython-38.pyc
# __init__.cpython-38.pyc
# dbapi2.cpython-38.pyc
# __init__.cpython-38.pyc
# abc.cpython-38.pyc
# machinery.cpython-38.pyc
# util.cpython-38.pyc
# __init__.cpython-38.pyc
# abc.cpython-38.pyc
# wb_admin_logs.cpython-38.pyc
# code_utils_grt.cpython-38.pyc
# migration_source_selection.cpython-38.pyc
# wb_admin_perfschema_instrumentation.cpython-38.pyc
# db_sqlite_re_grt.cpython-38.pyc
# wb_admin_config_file_be.cpython-38.pyc
# explain_renderer.cpython-38.pyc
# wb_query_analysis_grt.cpython-38.pyc
# sqlide_schematree_ext.cpython-38.pyc
# wb_model_utils.cpython-38.pyc
# db_sql92_re_grt.cpython-38.pyc
# migration_grt.cpython-38.pyc
# sql_reformatter.cpython-38.pyc
# sqlide_power_import_wizard.cpython-38.pyc
# wb_admin_perfschema_instrumentation_be.cpython-38.pyc
# wb_log_reader.cpython-38.pyc
# wb_server_management.cpython-38.pyc
# wb_admin_export.cpython-38.pyc
# wb_admin_variable_list.cpython-38.pyc
# db_sql92_migration_grt.cpython-38.pyc
# migration_schema_selection.cpython-38.pyc
# wb_common.cpython-38.pyc
# wb_server_control.cpython-38.pyc
# wb_admin_configuration_startup.cpython-38.pyc
# run_script.cpython-38.pyc
# migration_project_management.cpython-38.pyc
# text_grt.cpython-38.pyc
# sqlide_tableman_ext.cpython-38.pyc
# sqlide_grt.cpython-38.pyc
# migration_toolbars.cpython-38.pyc
# migration_main.cpython-38.pyc
# sqlide_resultset_ext.cpython-38.pyc
# table_utils_grt.cpython-38.pyc
# db_copy_overview.cpython-38.pyc
# wb_admin_grt.cpython-38.pyc
# migration_object_editing.cpython-38.pyc
# wba_ssh_ui.cpython-38.pyc
# db_mssql_migration_grt.cpython-38.pyc
# text_output.cpython-38.pyc
# migration.cpython-38.pyc
# db_sqlite_migration_grt.cpython-38.pyc
# wb_admin_perfschema_reports.cpython-38.pyc
# opts.cpython-38.pyc
# db_copy_source_target.cpython-38.pyc
# wb_admin_config_file_ui.cpython-38.pyc
# db_sybase_re_grt.cpython-38.pyc
# wb_admin_monitor.cpython-38.pyc
# migration_object_migration.cpython-38.pyc
# wb_admin_control.cpython-38.pyc
# wb_admin_export_options.cpython-38.pyc
# db_postgresql_re_grt.cpython-38.pyc
# migration_summary.cpython-38.pyc
# db_sqlanywhere_migration_grt.cpython-38.pyc
# sqlide_import_spatial.cpython-38.pyc
# table_templates.cpython-38.pyc
# db_sqlanywhere_re_grt.cpython-38.pyc
# wb_utils_grt.cpython-38.pyc
# db_copy_main.cpython-38.pyc
# db_sybase_migration_grt.cpython-38.pyc
# wb_admin_security_be.cpython-38.pyc
# db_copy_schema_selection.cpython-38.pyc
# wba_monitor_be.cpython-38.pyc
# wb_admin_security.cpython-38.pyc
# migration_bulk_copy_data.cpython-38.pyc
# db_generic_re_grt.cpython-38.pyc
# DataMigrator.cpython-38.pyc
# db_mysql_fe_grt.cpython-38.pyc
# wb_dev_utils_grt.cpython-38.pyc
# migration_overview.cpython-38.pyc
# db_copy_report.cpython-38.pyc
# sqlide_catalogman_ext.cpython-38.pyc
# db_mssql_grt.cpython-38.pyc
# wb_admin_connections.cpython-38.pyc
# migration_object_selection.cpython-38.pyc
# migration_data_transfer.cpython-38.pyc
# wb_catalog_utils.cpython-38.pyc
# wb_admin_perfschema.cpython-38.pyc
# migration_ui_style.cpython-38.pyc
# wb_admin_performance_dashboard.cpython-38.pyc
# db_mysql_re_grt.cpython-38.pyc
# SQLEXT.cpython-38.pyc
# migration_schema_creation.cpython-38.pyc
# db_mysql_migration_grt.cpython-38.pyc
# db_generic_migration_grt.cpython-38.pyc
# db_postgresql_migration_grt.cpython-38.pyc
# sqlide_power_import_export_be.cpython-38.pyc
# db_copy_progress.cpython-38.pyc
# sqlide_power_export_wizard.cpython-38.pyc
# db_copy_grt.cpython-38.pyc
# wb_admin_server_status.cpython-38.pyc
# wb_admin_utils.cpython-38.pyc
# wb_admin_variables.cpython-38.pyc
# wb_admin_main.cpython-38.pyc
# mforms.cpython-38.pyc
# cairo.cpython-38.pyc
# wb.cpython-38.pyc
# __init__.cpython-38.pyc
# database_schema_selector_widget.cpython-38.pyc
# db_driver.cpython-38.pyc
# os_utils.cpython-38.pyc
# ui.cpython-38.pyc
# utils.cpython-38.pyc
# database_object_selector_widget.cpython-38.pyc
# client_utils.cpython-38.pyc
# log.cpython-38.pyc
# wizard_progress_page_widget.cpython-38.pyc
# template.cpython-38.pyc
# tcp_utils.cpython-38.pyc
# change_tracker.cpython-38.pyc
# wizard_page_widget.cpython-38.pyc
# db_utils.cpython-38.pyc
# plugins.cpython-38.pyc
# exceptions.cpython-38.pyc
# notifications.cpython-38.pyc
# wizard_form.cpython-38.pyc
# __init__.cpython-38.pyc
# charting.cpython-38.pyc
# cairo_utils.cpython-38.pyc
# canvas.cpython-38.pyc
# site.cpython-38.pyc
# tempfile.cpython-38.pyc
# operator.cpython-38.pyc
# reprlib.cpython-38.pyc
# stat.cpython-38.pyc
# shlex.cpython-38.pyc
# string.cpython-38.pyc
# base64.cpython-38.pyc
# dis.cpython-38.pyc
# queue.cpython-38.pyc
# lzma.cpython-38.pyc
# random.cpython-38.pyc
# socketserver.cpython-38.pyc
# _sitebuiltins.cpython-38.pyc
# sre_compile.cpython-38.pyc
# io.cpython-38.pyc
# functools.cpython-38.pyc
# pickle.cpython-38.pyc
# re.cpython-38.pyc
# platform.cpython-38.pyc
# pprint.cpython-38.pyc
# copyreg.cpython-38.pyc
# genericpath.cpython-38.pyc
# fnmatch.cpython-38.pyc
# warnings.cpython-38.pyc
# abc.cpython-38.pyc
# enum.cpython-38.pyc
# bisect.cpython-38.pyc
# subprocess.cpython-38.pyc
# copy.cpython-38.pyc
# selectors.cpython-38.pyc
# _bootlocale.cpython-38.pyc
# locale.cpython-38.pyc
# opcode.cpython-38.pyc
# sre_parse.cpython-38.pyc
# posixpath.cpython-38.pyc
# traceback.cpython-38.pyc
# types.cpython-38.pyc
# weakref.cpython-38.pyc
# csv.cpython-38.pyc
# signal.cpython-38.pyc
# socket.cpython-38.pyc
# contextlib.cpython-38.pyc
# tokenize.cpython-38.pyc
# pipes.cpython-38.pyc
# difflib.cpython-38.pyc
# os.cpython-38.pyc
# linecache.cpython-38.pyc
# _compat_pickle.cpython-38.pyc
# _collections_abc.cpython-38.pyc
# sre_constants.cpython-38.pyc
# keyword.cpython-38.pyc
# heapq.cpython-38.pyc
# token.cpython-38.pyc
# _compression.cpython-38.pyc
# getpass.cpython-38.pyc
# _weakrefset.cpython-38.pyc
# shutil.cpython-38.pyc
# datetime.cpython-38.pyc
# zipfile.cpython-38.pyc
# bz2.cpython-38.pyc
# struct.cpython-38.pyc
# ntpath.cpython-38.pyc
# codecs.cpython-38.pyc
# calendar.cpython-38.pyc
# inspect.cpython-38.pyc
# threading.cpython-38.pyc
# aliases.cpython-38.pyc
# __init__.cpython-38.pyc
# cp437.cpython-38.pyc
# latin_1.cpython-38.pyc
# utf_8.cpython-38.pyc
# ascii.cpython-38.pyc
# __init__.cpython-38.pyc
# _endian.cpython-38.pyc
# __init__.cpython-38.pyc
# context.cpython-38.pyc
# process.cpython-38.pyc
# reduction.cpython-38.pyc
# __init__.cpython-38.pyc
# decoder.cpython-38.pyc
# encoder.cpython-38.pyc
# scanner.cpython-38.pyc
# __init__.cpython-38.pyc
# dbapi2.cpython-38.pyc
# __init__.cpython-38.pyc
# abc.cpython-38.pyc
# machinery.cpython-38.pyc
# util.cpython-38.pyc
# __init__.cpython-38.pyc
# abc.cpython-38.pyc
# Cache.db-shm
# Cache.db-wal
# Cache.db
# spotlight_model_resources
# silhouette_data
# bag.plist
# spotlight_phrase_dictionary.map
# session.835.41620D7E-211B-48B7-913A-A6F8D426098C.closed
# qi_features_url
# dictionary_resources_url
# silhouette_topic_mapping
# persistent.json
# crowdsourcing_blacklist_url
# crowdsourcing_whitelist_url
# installed_app_whitelist_url
# spotlight_stopword.map
# silhouette_whitelisted_topics
# silhouette_config
# correction_dict_url
# autofill_tld_whitelist_url
# session.835.70487770-A0E9-4840-897D-0CF79E4A89F8.open
# session.835.75B6F4CA-144F-4FED-876C-886F263E5F6E.open
# cohorts.sqlite
# cohorts.sqlite-shm
# cohorts.sqlite-wal
# Cache.db
# Cache.db-shm
# Cache.db-wal
# Cache.db
# E941DB97-142C-43D3-B081-AC09FCF8F3DC
# Cache.db-shm
# Cache.db-wal
# Cache.db
# 96064B11-0C21-4EEA-9F5B-F20CF0796A78
# 5E3EB9E2-AB85-4F61-9D00-98C1D719E8A6
# HSTS.plist
# Cache.db-shm
# Cache.db-wal
# Cache.db
# E432A10E-052D-46A8-A089-1F964665A63C
# 5C9646E6-BB34-4BA2-87DB-D573FFF3DCE4
# 71BCC86E-4E6B-4662-819B-5A05BDFF7EB2
# E8180333-D786-4E35-907F-5F8837DEC700
# latest-logging-config.data
# cached-logging-config.data
# data.sqlite-wal
# data.sqlite-shm
# data.sqlite
# Cache.db-shm
# Cache.db-wal
# Cache.db
# Cache.db-shm
# Cache.db-wal
# Cache.db
# BB66B29C-4F07-46B6-B57B-4B97CB4C18CA
# Cache.db-shm
# Cache.db-wal
# Cache.db
# 72EB0B9E-DE6B-4DED-9F49-1BC341E179FA
# Cache.db-shm
# Cache.db-wal
# Cache.db
# 8DA51834-A11B-47D5-9660-FC45E253B00E
# Cache.db-shm
# Cache.db-wal
# Cache.db
# 81D8A510-B566-4692-BC00-7AE266901AC9
# 618C9493-73AB-46BA-91FB-111E83985F87
# BA6690ED-C65A-4D5F-84C6-4EE21639A9EE
# 4FCA9278-ABCD-4459-A8B9-4D182D867D4F
# 184E2E95-1E38-4A06-82FC-AE90697A58CB
# 26B8EF16-AD5C-422D-B774-E31B66A28503
# FD422D0E-B09D-47E0-AA5B-EB9007DA2697
# 55A7B429-C700-47C6-A8F9-83E1474A8FFB
# AA3065FB-C8C8-4E86-BDB4-C1220A458135
# Cache.db-shm
# Cache.db-wal
# Cache.db
# 2BB5FBEF-5C09-4068-9F5B-C68E1CBA7951
# CacheDeleteRecentInfo_v2
# CDPurgeStats
# CacheDeleteAnalytics.plist
# Cache.db-shm
# Cache.db-wal
# Cache.db
# HSTS.plist
# 0F5D7E61-8862-4940-8333-875656FE1F45
# AAProfilePicture_48DD39FF-53E3-4C70-9001-13A272F66D48.png
# Cache.db-shm
# Cache.db-wal
# Cache.db
# HSTS.plist
# 50B9F4B6-6794-4AC1-A9C1-E566EB7FDCFD
# 11DB6E90-3806-4655-B469-ABC8D613A655
# 06ECBF24-15AC-481A-ABDC-33E99BB6CF4B
# 51FDF3FC-5557-47E4-BCC1-5DFCEED2D14E
# 716DF93E-23F4-4BE8-8461-C412F1C56625
# Cache.db-shm
# Cache.db-wal
# Cache.db
# A63509CA-F380-44F6-88E2-669CF8D60A9E
# 476F6D10-FA4E-4189-AFEE-C869ECCD7CC4
# itunescloudd.plist
# assistant_service.plist
# fontlist-v330.json
# iris.csv
# .localized
# .localized
# navigator_updater.lock
# anaconda-navigator.ini
# navigator.lock
# navigator.pid
# content.json
# events.json
# webinars.json
# videos.json
# defaults-2.0.0.ini
# navigator_updater.log
# navigator.log
# anaconda-navigator-updater.sh
# notebook.sh
# metadata.json
# .localized
# .Media Preferences.plist
# id.strings
# es.strings
# no.strings
# zh_TW.strings
# fi.strings
# ru.strings
# en.strings
# es_419.strings
# he.strings
# uk.strings
# fr_CA.strings
# nl.strings
# de.strings
# ja.strings
# sk.strings
# hr.strings
# el.strings
# th.strings
# zh_CN.strings
# cs.strings
# sv.strings
# pl.strings
# zh_HK.strings
# en_GB.strings
# en_AU.strings
# da.strings
# fr.strings
# ro.strings
# pt.strings
# pt_PT.strings
# ms.strings
# ko.strings
# hu.strings
# hi.strings
# tr.strings
# vi.strings
# ca.strings
# ar.strings
# it.strings
# Library Preferences.tvdb
# Library.tvdb
# Untitled3-checkpoint.ipynb
# Python Basic Assignment 20 -Tavishi-checkpoint.ipynb
# ML- linear , Ridge, Lasso regression-checkpoint.ipynb
# Assignment_24_Soln-checkpoint.ipynb
# Python advance programming assignment_1 tavishi-checkpoint.ipynb
# Untitled2-checkpoint.ipynb
# Python Basic Assignment 11 -Tavishi-checkpoint.ipynb
# Assignment_22_Soln-checkpoint.ipynb
# live location -checkpoint.ipynb
# Untitled6-checkpoint.ipynb
# Python advance programming assignment_2 tavishi-checkpoint.ipynb
# Untitled1-checkpoint.ipynb
# Assignment_25_Soln-checkpoint.ipynb
# eda-7-million-company-dataset- tavishi -checkpoint.ipynb
# Python Basic Assignment 10 -Tavishi-checkpoint.ipynb
# Untitled-checkpoint.ipynb
# Decision Tree -checkpoint.ipynb
# Assignment_23_Soln-checkpoint.ipynb
# logistic regression -checkpoint.ipynb
# Assignment_21_Soln-checkpoint.ipynb
# Untitled4-checkpoint.ipynb
# EDA - India's Weather And Its Impact On Renewable Energy-checkpoint.ipynb
# migrated
# config.yaml
# E6868653-0E34-46BD-A811-67D2075CB4CE.historynew
# C48BD61D-A224-4B9F-9F5C-7D6C8C5B96B1.historynew
# 4E609969-B737-470B-A032-E02187FE4571.historynew
# 602AD114-A270-41CE-945D-CA215C4D962A.historynew

# %% [markdown]
# ## 5.Create a list of all of the files in your parent directory (minimum five files should be available).

# %%
import os 
os.listdir()
# Out:
# ['.config',
#  'Music',
#  'Assignment_23_Soln.ipynb',
#  'logistic regression .ipynb',
#  '.condarc',
#  'Python Basic Assignment 20 -Tavishi.ipynb',
#  'mylocation2.html',
#  'Untitled1.ipynb',
#  '.DS_Store',
#  '.CFUserTextEncoding',
#  '.xonshrc',
#  'Untitled3.ipynb',
#  'Untitled.ipynb',
#  'Assignment_21_Soln.ipynb',
#  '.zshrc',
#  'today.txt',
#  'Untitled4.ipynb',
#  'Untitled6.ipynb',
#  'Pictures',
#  'Untitled2.ipynb',
#  '.ipython',
#  'Desktop',
#  'Library',
#  '.matplotlib',
#  'Assignment_24_Soln.ipynb',
#  'seaborn-data',
#  'Python advance programming assignment_1 tavishi.ipynb',
#  'Python Basic Assignment 11 -Tavishi.ipynb',
#  'abc.zip',
#  'Public',
#  'mylocation.html',
#  '.tcshrc',
#  'ML- linear , Ridge, Lasso regression.ipynb',
#  '.anaconda',
#  'Assignment_22_Soln.ipynb',
#  'xyz.zip',
#  "EDA - India's Weather And Its Impact On Renewable Energy.ipynb",
#  'Movies',
#  'Python advance programming assignment_2 tavishi.ipynb',
#  'Python Basic Assignment 10 -Tavishi.ipynb',
#  '.Trash',
#  'test.txt',
#  '.ipynb_checkpoints',
#  '.jupyter',
#  'live location .ipynb',
#  'Documents',
#  'Decision Tree .ipynb',
#  'Assignment_25_Soln.ipynb',
#  '.bash_profile',
#  'Downloads',
#  '.continuum',
#  'eda-7-million-company-dataset- tavishi .ipynb',
#  '.zsh_sessions',
#  '.conda']

# %% [markdown]
# ## 6. Use multiprocessing to create three separate processes. Make each one wait a random number of seconds between one and five, print the current time, and then exit.

# %%
import multiprocessing
import time 
import random
import datetime

def procOne():
    print(f'Proc_one_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Proc_one_Endtime -> {datetime.datetime.now()}')
    
def procTwo():
    print(f'Proc_two_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Proc_two_Endtime -> {datetime.datetime.now()}')

def procThree():
    print(f'Proc_two_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Proc_two_Endtime -> {datetime.datetime.now()}')
    
if __name__ == "__main__":    
    p1 = multiprocessing.Process(target=procOne)
    p2 = multiprocessing.Process(target=procTwo)
    p3 = multiprocessing.Process(target=procThree)

    p1.start()
    p2.start()
    p3.start()

    p1.join()
    p2.join()
    p3.join()
# Out:
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
# AttributeError: Can't get attribute 'procOne' on <module '__main__' (built-in)>
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
# AttributeError: Can't get attribute 'procTwo' on <module '__main__' (built-in)>
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
# AttributeError: Can't get attribute 'procThree' on <module '__main__' (built-in)>

# %% [markdown]
# ## 7.Create a date object of your day of birth.

# %%
from datetime import datetime
my_dob = datetime.strptime('12/02/1992','%d/%m/%Y')
print(my_dob, type(my_dob))
# Out:
# 1992-02-12 00:00:00 <class 'datetime.datetime'>

# %% [markdown]
#
# ## 8. What day of the week was your day of birth?
#
#
#
# - With weekday(), Monday is 0 and Sunday is 6.
# - With isoweekday(), Monday is 1 and Sunday is 7. Therefore, this date is a friday.

# %%
from datetime import datetime
my_dob = datetime(1992,2,14)
my_dob.strftime("%A")
# Out:
# 'Friday'

# %%
my_day.weekday()
# Out:
# 4

# %%
my_day.isoweekday()
# Out:
# 5

# %% [markdown]
# ## 9. When will you be (or when were you) 10,000 days old?

# %%
from datetime import timedelta
ten_thousand = my_day + timedelta(days=10000)
ten_thousand
# Out:
# datetime.date(2019, 7, 2)
